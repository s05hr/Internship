# %% [markdown]
# # ASSIGNMENT 2---WEB SCRAPING USING SELENIUM

# %%
import selenium     #import respective libraries for web scraping using selenium
import pandas as pd 
from selenium import webdriver 
import warnings    
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException 
from selenium.webdriver.common.by import By
import time

# %% [markdown]
# #Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10 jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Analyst” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.
# Note: All of the above steps have to be done in code. No step is to be done manually.

# %%
# first connect to the driver-
driver=webdriver.Chrome(r"D:\chromedriver_win32.zip\chromedriver.exe")

#opening the naukari page on automated chrome browser
driver.get("https://www.naukri.com/")

# %%
#entering designation and location as required in the question-
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Analyst')    

location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys('Bangalore')

search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

#scraping job title from the given page
title_tags=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
#scraping job location from the given page
location_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
#scraping company name from the given page
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
#scraping job experience from the given page
experience_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]')
for i in experience_tags[0:10]:
    exp=i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))  # length of the given data
# Out:
# 10 10 10 10

# %%
#creating the dataframe from above data-
df=pd.DataFrame({'job_title':job_title,'job_location':job_location,'company_name':company_name,'Exp_required':experience_required})
df
# Out:
#                         job_title                        job_location  \
# 0                    Data Analyst                 Bangalore/Bengaluru
# 1                    Data Analyst                 Bangalore/Bengaluru
# 2                    Data Analyst                 Bangalore/Bengaluru
# 3          Senior Data Analyst II                 Bangalore/Bengaluru
# 4            Project Data Analyst                 Bangalore/Bengaluru
# 5  Data Analyst, Business Analyst  Bangalore/Bengaluru(HSR Layout +1)
# 6                    Data Analyst     Temp. WFH - Bangalore/Bengaluru
# 7        Executive - Data Analyst                 Bangalore/Bengaluru
# 8                    Data Analyst                 Bangalore/Bengaluru
# 9                    Data Analyst                 Bangalore/Bengaluru
#
#                          company_name Exp_required
# 0                       Shell Pvt Ltd      2-5 Yrs
# 1                       Shell Pvt Ltd      3-5 Yrs
# ...

# %% [markdown]
# Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Scientist” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.
# Note: All of the above steps have to be done in code. No step is to be done manually.

# %%
#first connect to the driver-
driver=webdriver.Chrome(r"D:\chromedriver_win32.zip\chromedriver.exe")

#opening the naukari page on automated chrome browser
driver.get("https://www.naukri.com/")

# %%
#entering designation and location as required in the question-

designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys('Bangalore')

search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

#scraping job title from the given page
title_tags=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
#scraping job location from the given page
location_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
#scraping company name from the given page
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
#scraping job experience from the given page
experience_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]')
for i in experience_tags[0:10]:
    exp=i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required)) # length of the given data
# Out:
# 10 10 10 10

# %%
#creating the dataframe from above data-
df=pd.DataFrame({'job_title':job_title,'job_location':job_location,'company_name':company_name,'Exp_required':experience_required})
df
# Out:
#                                           job_title  \
# 0                  Analystics & Modeling Specialist
# 1                                    Data Scientist
# 2                                    Data Scientist
# 3      Data & Analytics Lead, Geo Analytics - GAMMA
# 4                Weather and Climate Data Scientist
# 5                                    Data Scientist
# 6                               Data Scientist - II
# 7                             Senior Data Scientist
# 8                              Manager-Data Science
# 9  ACN - Applied Intelligence - Data Scientist - 09
#
#                                         job_location             company_name  \
# 0  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...                Accenture
# 1  Bangalore/Bengaluru, New Delhi, Hyderabad/Secu...              Tata Nexarc
# 2                  Bangalore/Bengaluru, Nagpur, Pune            Tech Mahindra
# ...

# %% [markdown]
# Q3: In this question you have to scrape data using the filters on the webpage:
# You have to use the location and salary filter.
# You have to scrape data for “Data Scientist” designation for first 10 job results. You have to scrape the job-title, job-location, company name, experience required.
# The location filter to be used is “Delhi/NCR”. The salary filter to be used is “3-6” lakhs
# The task will be done as shown in the below steps:
# 1. first get the webpage https://www.naukri.com/
# 2. Enter “Data Scientist” in “Skill, Designations, and Companies” field.
# 3. Then click the search button.
# 4. Then apply the location filter and salary filter by checking the respective boxes
# 5. Then scrape the data for the first 10 jobs results you get.
# 6. Finally create a dataframe of the scraped data.
# Note: All of the above steps have to be done in code. No step is to be done manually.

# %%
#first connect to the driver-
driver=webdriver.Chrome(r"D:\chromedriver_win32.zip\chromedriver.exe")

#opening the naukari page on automated chrome browser
driver.get("https://www.naukri.com/")

# %%
#entering designation as required in the question-
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()
time.sleep(5)

# %%
#entering location from the given page
location_tags=driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[1]/div[2]/div[4]/label/p/span[1]')
location_tags.click()
time.sleep(5)

# %%
#entering salary filter from the given page
salary_tags=driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[6]/div[2]/div[2]/label/p/span[1]')
salary_tags.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

#scraping job title from the given page
title_tags=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    job_title.append(i.text)
    
#scraping job location from the given page
location_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location_tags[0:10]:
    job_location.append(i.text)
    
#scraping company name from the given page
company_tags=driver.find_elements(By.XPATH,'//div[@class="mt-7 companyInfo subheading lh16"]')
for i in company_tags[0:10]:
    company_name.append(i.text)
    
#scraping job experience from the given page
experience_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]')
for i in experience_tags[0:10]:
    experience_required.append(i.text)

# %%
#creating the dataframe from above data-
df=pd.DataFrame({'job_title':job_title,'job_location':job_location,'company_name':company_name,'Exp_required':experience_required})
df
# Out:
#                                            job_title  \
# 0  Urgent Hiring || Java Full Stack Developer || ...
# 1                                Wordpress Develoepr
# 2  HCL Technologies Hiring For Java Full Stack De...
# 3  HCL Technologies Hiring For Java Full Stack De...
# 4                        Java Microservice Developer
# 5  Java Developer: Java, Microservices, Springboo...
# 6                 Senior Software Engineer- HL7 V2.x
# 7                    Senior Java Fullstack Developer
# 8                                             Intern
# 9                                  Tableau Developer
#
#                                         job_location  \
# 0  Hybrid - Bhubaneswar, Kolkata, Hyderabad/Secun...
# 1  Vijayawada, Hyderabad/Secunderabad, Pune, Bang...
# 2  Hybrid - Noida, Hyderabad/Secunderabad, Pune, ...
# 3  Hybrid - Kolkata, Hyderabad/Secunderabad, Pune...
# 4  Hybrid - Pune, Bangalore/Bengaluru, Mumbai (Al...
# 5  Pune, Ahmedabad, Chennai, Bangalore/Bengaluru,...
# ...

# %% [markdown]
# Q4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
# 1. Brand
# 2. Product Description
# 3. Price
# To scrape the data you have to go through following steps:
# 1. Go to Flipkart webpage by url : https://www.flipkart.com/
# 2. Enter “sunglasses” in the search field where “search for products, brands and more” is written and click the search icon
# 3. After that you will reach to the page having a lot of sunglasses. From this page you can scrap the required data as usual.
# 4. After scraping data from the first page, go to the “Next” Button at the bottom other page , then
# click on it.
# 5. Now scrape data from this page as usual
# 6. Repeat this until you get data for 100 sunglasses.
# Note: That all of the above steps have to be done by coding only and not manually.

# %%
#first connect to the driver-
driver=webdriver.Chrome(r"D:\chromedriver_win32.zip\chromedriver.exe")

#opening the flipkart page on automated chrome browser
driver.get("https://www.flipkart.com/")
time.sleep(5)

# %%
#close the pop window
close_button=driver.find_element(By.XPATH,"/html/body/div[2]/div/div/button").click()

# %%
#entering product name as mentioned in the question-
product=driver.find_element(By.CLASS_NAME,"_3704LK")
product.send_keys('Sunglasses')

search=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
#scrap data from the next pages
next_button=driver.find_elements(By.XPATH,'//a[@class="_1LKTO3"]')
next_button
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="9f2ec8bc971cfcd9ab722e489e847f4d", element="ee8b0da7-c33c-4b0d-9e9b-d658c04225bf")>]

# %%
product_brand=[]
product_discription=[]
product_price=[]
product_discount=[]

start=0
end=3
for page in range(start,end):  
    brand=driver.find_elements(By.XPATH,"//div[@class='_2WkVRV']") #scrap brand names from the given page
    description=driver.find_elements(By.XPATH,"//div[@class='_2B099V']") #scrap decription of products from the given page
    price =driver.find_elements(By.XPATH,"//div[@class='_30jeq3']")#scrap price of products from the given page
    discount=driver.find_elements(By.XPATH,"//div[@class='_3Ay6Sb']") #scrap discount of the products from the given page 
    
    for i in brand:
        product_brand.append(i.text)
    print(product_brand[:100])
    
    for j in description:
        product_discription.append(j.text)
    print(product_discription[:100])
    
    for k in price:
        product_price.append(k.text)
    print(product_price[:100])
        
    for m in discount:
        product_discount.append(m.text)
    print(product_discount[:100])
# Out:
# ['VINCENT CHASE', 'VINCENT CHASE', 'LIZA ANGEL', 'Fastrack', 'Fastrack', 'Elligator', 'PHENOMENAL', 'ROZZETTA CRAFT', 'Elligator', 'SHAAH COLLECTIONS', 'Singco India', 'ROZZETTA CRAFT', 'Elligator', 'Fastrack', 'Elligator', 'SRPM', 'VINCENT CHASE', 'VINCENT CHASE', 'Elligator', 'New Specs', 'VINCENT CHASE', 'ROZZETTA CRAFT', 'LIZA ANGEL', 'Fastrack', 'Fastrack', 'SRPM', 'VINCENT CHASE', 'VINCENT CHASE', 'LIZA ANGEL', 'PIRASO', 'VINCENT CHASE', 'ROZZETTA CRAFT', 'SUNBEE', 'Fastrack', 'New Specs', 'PIRASO', 'ROZZETTA CRAFT', 'ROYAL SON', 'Fastrack', 'Fastrack']
# ...

# %%
#creating the dataframe from above data-
df=pd.DataFrame({'product_brand':product_brand[:100],'product_discription':product_discription[:100],'product_price':product_price[:100],'product_discount':product_discount[:100]})
df
# Out:
#     product_brand                                product_discription  \
# 0   VINCENT CHASE  VINCENT CHASE\nby Lenskart Polarized, UV Prote...
# 1   VINCENT CHASE  VINCENT CHASE\nby Lenskart Polarized, UV Prote...
# 2      LIZA ANGEL  LIZA ANGEL\nRiding Glasses, Night Vision Spect...
# 3        Fastrack  Fastrack\nUV Protection Rectangular Sunglasses...
# 4        Fastrack  Fastrack\nUV Protection Wayfarer Sunglasses (F...
# ..            ...                                                ...
# 95           SRPM  SRPM\nUV Protection Wayfarer Sunglasses (50)\n...
# 96  VINCENT CHASE  VINCENT CHASE\nby Lenskart Polarized, UV Prote...
# 97  VINCENT CHASE  VINCENT CHASE\nby Lenskart Polarized, UV Prote...
# 98      Elligator  Elligator\nUV Protection Round Sunglasses (54)...
# 99      New Specs  New Specs\nUV Protection Rectangular Sunglasse...
#
#    product_price product_discount
# 0           ₹806          59% off
# 1           ₹849          57% off
# ...

# %% [markdown]
# Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to go the link: https://www.flipkart.com/apple-iphone-11-black-64-gb/product- reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market place=FLIPKART
#    As shown in the above page you have to scrape the tick marked attributes. These are:
# 1. Rating
# 2. Review summary
# 3. Full review
# 4. You have to scrape this data for first 100 reviews.
# Note: All the steps required during scraping should be done through code only and not manually.

# %%
#first connect to the driver-
driver=webdriver.Chrome(r"D:\chromedriver_win32.zip\chromedriver.exe")

# %%
#opening the flipkart product review page on automated chrome browser
driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market")

# %%
Rating=[]
Review_summary=[]
Full_review=[]

start=0
end=10
for page in range(start,end):
    rating=driver.find_elements(By.XPATH,"//div[@class='_3LWZlK _1BLPMq']") #scrap ratings from the given page
    review_summary=driver.find_elements(By.XPATH,"//p[@class='_2-N8zT']") #scrap review summaries from the given page
    full_review=driver.find_elements(By.XPATH,"//div[@class='t-ZTKy']") #scrap full review of the product from the given page
   
    
    for i in rating:
        Rating.append(i.text)
    
    for j in review_summary:
        Review_summary.append(j.text)
    
    for k in full_review:
        Full_review.append(k.text)
        
    next_button=driver.find_elements(By.XPATH,'//a[@class="_1LKTO3"]') #scrap data from the  next page
    next_button

# %%
print(len(Rating),len(Review_summary),len(Full_review)) #length of the datas
# Out:
# 100 100 100

# %%
#creating the dataframe from above data-
df=pd.DataFrame({'Ratings':Rating[:100],'Review_summary':Review_summary[:100],'Full_review':Full_review[:100]})
df
# Out:
#    Ratings       Review_summary  \
# 0        5       Simply awesome
# 1        5     Perfect product!
# 2        5  Best in the market!
# 3        4      Value-for-money
# 4        5    Worth every penny
# ..     ...                  ...
# 95       5   Highly recommended
# 96       5   Highly recommended
# 97       5     Perfect product!
# 98       5        Great product
# 99       4          Pretty good
#
#                                           Full_review
# 0   Really satisfied with the Product I received.....
# 1   Amazing phone with great cameras and better ba...
# 2   Great iPhone very snappy experience as apple k...
# 3   I'm Really happy with the product\nDelivery wa...
# 4   Previously I was using one plus 3t it was a gr...
# ..                                                ...
# 95  It's my first time to use iOS phone and I am l...
# 96  What a camera .....just awesome ..you can feel...
# 97  Value for money\n5 star rating\nExcellent came...
# ...

# %% [markdown]
# Q6: Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the search field.
# You have to scrape 4 attributes of each sneaker:
# 1. Brand
# 2. Product Description
# 3. Price

# %%
#first connect to the driver-
driver=webdriver.Chrome(r"D:\chromedriver_win32.zip\chromedriver.exe")

# %%
#opening the flipkart page on automated chrome browser
driver.get("https://www.flipkart.com/")

# %%
#close the pop up login window
close_button=driver.find_element(By.XPATH,"/html/body/div[2]/div/div/button").click()
time.sleep(5)

# %%
#entering product name as mentioned in ques
product=driver.find_element(By.CLASS_NAME,"_3704LK")
product.send_keys('Sneakers')

search=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
Brand=[]
Product_description=[]
Price=[]

start=0
end=3
for page in range(start,end):
    brand=driver.find_elements(By.XPATH,"//div[@class='_2WkVRV']") #scrap brand name from the given page
    product_description=driver.find_elements(By.XPATH,"//div[@class='_2B099V']")# scrap product description from the given page
    price=driver.find_elements(By.XPATH,"//div[@class='_30jeq3']")#scrap price of the product from the given page
   
    
    for i in brand:
        Brand.append(i.text)
    
    for j in product_description:
        Product_description.append(j.text)
    
    for k in price:
        Price.append(k.text)
        
    next_button=driver.find_elements(By.XPATH,'//a[@class="ge-49M"]')#scrap data from the next page
    next_button

# %%
#creating the dataframe from above data-
df=pd.DataFrame({'Brand':Brand[:100],'Product_description':Product_description[:100],'Price':Price[:100]})
df
# Out:
#                       Brand  \
# 0                     Sparx
# 1                     Sparx
# 2                    Labbin
# 3                    Shozie
# 4                    Kzaara
# ..                      ...
# 95      World Wear Footwear
# 96           Mast & Harbour
# 97                     PUMA
# 98  Bond Street By Red Tape
# 99                Deals4you
#
#                                   Product_description   Price
# 0   Sparx\nSM-162 Sneakers For Men\n₹1,079\nFree d...  ₹1,079
# 1   Sparx\nSneakers For Women\n₹879₹1,09920% off\n...    ₹879
# 2   Labbin\nSneakers For Men\n₹399₹99960% off\nFre...    ₹399
# 3   Shozie\nSneakers For Men\n₹295₹99970% off\nFre...    ₹295
# 4   Kzaara\nSneakers For Men\n₹229₹99977% off\nFre...    ₹229
# ..                                                ...     ...
# 95  World Wear Footwear\nExclusive Affordable Coll...    ₹259
# 96  Mast & Harbour\nSneakers For Men\n₹824₹2,09960...    ₹824
# ...

# %% [markdown]
# Q7: Go to webpage https://www.amazon.in/
# Enter “Laptop” in the search field and then click the search icon.
# Then set CPU Type filter to “Intel Core i7”.
# After setting the filters scrape first 10 laptops data. You have to scrape 3 attributes for each laptop:
# 1. Title
# 2. Ratings
# 3. Price

# %%
#first connect to the driver-
driver=webdriver.Chrome(r"D:\chromedriver_win32.zip\chromedriver.exe")

# %%
#opening the amazon page on automated chrome browser
driver.get('https://www.amazon.in/')

# %%
#enter laptop on search bar
search_g= driver.find_element(By.XPATH,"//input[@type='text']")
search_g.send_keys('Laptop')

#click on search button
search_btn=driver.find_element(By.XPATH,"//input[@id='nav-search-submit-button']")
search_btn.click()

# %%
#entering CPU filter from the given page
cpu=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[5]/ul[6]/li[11]/span/a/span')
cpu.click()

# %%
Title=[]
Ratings=[]
Price=[]

#scraping titles from the given page
title_tags=driver.find_elements(By.XPATH,'//span[@class="a-size-medium a-color-base a-text-normal"]')
for i in title_tags[0:10]:
    Title.append(i.text)
    
#scraping ratings from the given page
rating_tags=driver.find_elements(By.XPATH,'//span[@class="a-icon-alt"]')
for i in rating_tags[0:10]:
    Ratings.append(i.text)

#scraping prices from the given page
price_tags=driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
for i in price_tags[0:10]:
    Price.append(i.text)

# %%
#creating the dataframe from above data-
df=pd.DataFrame({'Title':Title,'Ratings':Ratings,'Price':Price})
df
# Out:
#                                                Title Ratings     Price
# 0  Acer Predator Helios 300 Gaming Laptop Intel C...          1,15,990
# 1  Dell New Alienware x15 R2 Gaming Laptop, Intel...          3,56,600
# 2  ASUS Zenbook Pro 14 Duo OLED (2022) Dual Scree...          2,14,990
# 3  HP Omen 12th Gen Intel Core i9-12900HX 17.3 in...          3,39,500
# 4  Acer Predator Helios 300 Gaming Laptop Intel C...          1,49,990
# 5  Acer Predator Helios 300 Gaming Laptop Intel C...          1,89,990
# 6  MSI Raider GE67 HX 12UHS,Intel 12th Gen. Core ...          4,29,990
# 7  Dell G15-5521 Gaming Laptop, i9-12900H, 16GB D...          1,81,833
# 8  Acer Predator Helios 500 Gaming Laptop (11Th G...          4,32,435
# 9  Hp Envy 15- 11Th Gen Intel Core I9/32Gb/1Tb Ss...          1,87,990

# %% [markdown]
# Q8: Write a python program to scrape data for Top 1000 Quotes of All Time.
# The above task will be done in following steps:
# 1. First get the webpage https://www.azquotes.com/
# 2. Click on Top Quotes
# 3. Than scrap a) Quote b) Author c) Type Of Quotes

# %%
#first connect to the driver-
driver=webdriver.Chrome(r"D:\chromedriver_win32.zip\chromedriver.exe")

#opening the azquotes page on automated chrome browser
driver.get("https://www.azquotes.com/")

time.sleep(5)# stop the search engine for the specified number of seconds

# %%
#click on the top quotes as mentioned in the ques 
product=driver.find_element(By.XPATH,'//a[@href="/top_quotes.html"]')
product.click()

# %%
Quote=[]
Author=[]
Type_of_quote=[]

start=0
end=10
for page in range(start,end):
    quote=driver.find_elements(By.XPATH,"//a[@class='title']") #scrap quotes from the page
    author=driver.find_elements(By.XPATH,"//div[@class='author']") #scrap author name from the page
    type_of_quote=driver.find_elements(By.XPATH,"//div[@class='tags']")#scrap type of quotes from the page
   
    
    for i in quote:
        Quote.append(i.text)
    
    for j in author:
        Author.append(j.text)
    
    for k in type_of_quote:
        Type_of_quote.append(k.text)
        
    next_button=driver.find_elements(By.XPATH,'//div[@class="next"]')#scrap datas from the next pages
    next_button

# %%
#creating the dataframe from above data-
df=pd.DataFrame({'Quote':Quote[:1000],'Author':Author[:1000],'Type_of_quote':Type_of_quote[:1000]})
df
# Out:
#                                                  Quote                Author  \
# 0    The essence of strategy is choosing what not t...        Michael Porter
# 1    One cannot and must not try to erase the past ...            Golda Meir
# 2    Patriotism means to stand by the country. It d...    Theodore Roosevelt
# 3    Death is something inevitable. When a man has ...        Nelson Mandela
# 4    You have to love a nation that celebrates its ...          Erma Bombeck
# ..                                                 ...                   ...
# 995     When the going gets weird, the weird turn pro.    Hunter S. Thompson
# 996  When a train goes through a tunnel and it gets...       Corrie Ten Boom
# 997  If you think you are too small to make a diffe...            Dalai Lama
# 998  God doesn't require us to succeed, he only req...         Mother Teresa
# 999    Change your thoughts and you change your world.  Norman Vincent Peale
#
# ...

# %% [markdown]
# Q9: Write a python program to display list of respected former Prime Ministers of India(i.e. Name, Born-Dead, Term of office, Remarks) from https://www.jagranjosh.com/.
# This task will be done in following steps:
# 1. First get the webpage https://www.jagranjosh.com/
# 2. Then You have to click on the GK option
# 3. Then click on the List of all Prime Ministers of India
# 4. Then scrap the mentioned data and make the DataFrame.

# %%
#connect to the driver
driver=webdriver.Chrome(r"D:\chromedriver_win32.zip\chromedriver.exe")

#open jagranjosh webpage on automated chrome browser
driver.get("https://www.jagranjosh.com/")

# %%
#click on the GK
product=driver.find_element(By.XPATH,'/html/body/div/div[1]/div/div[1]/div/div[6]/div/div[1]/header/div[3]/ul/li[9]/a')
product.click()

# %%
#click on the list of all prime minister of india
product=driver.find_element(By.XPATH,'/html/body/div[1]/div/div/div[2]/div/div[10]/div/div/ul/li[2]/a')
product.click()

# %%
Name=[]
Born_Dead=[]
Term_of_office=[]
Remarks=[]

#scrap names from the given table        
names = driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[2]/p')
for i in names:
    Name.append(i.text)

#scrap born-dead data from the table    
born_dead = driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[3]/p')
for j in born_dead:
    Born_Dead.append(j.text)

#scrap term of office from the table
term= driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[4]')
for k in term:
    Term_of_office.append(k.text)

#scrap remarks from the given table    
remarks= driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[5]/p')
for l in remarks:
    Remarks.append(l.text)

# %%
#create dataframe from the above data
df=pd.DataFrame({'Name':Name,'Born_Dead':Born_Dead,'Term_of_office':Term_of_office,'Remarks':Remarks})
df
# Out:
#                            Name     Born_Dead  \
# 0             Jawahar Lal Nehru   (1889–1964)
# 1     Gulzarilal Nanda (Acting)   (1898-1998)
# 2           Lal Bahadur Shastri   (1904–1966)
# 3   Gulzari Lal Nanda  (Acting)   (1898-1998)
# 4                 Indira Gandhi   (1917–1984)
# 5                 Morarji Desai   (1896–1995)
# 6                  Charan Singh   (1902–1987)
# 7                 Indira Gandhi   (1917–1984)
# 8                  Rajiv Gandhi   (1944–1991)
# 9                   V. P. Singh   (1931–2008)
# 10              Chandra Shekhar   (1927–2007)
# 11          P. V. Narasimha Rao   (1921–2004)
# 12         Atal Bihari Vajpayee  (1924- 2018)
# 13             H. D. Deve Gowda   (born 1933)
# 14           Inder Kumar Gujral   (1919–2012)
# 15         Atal Bihari Vajpayee   (1924-2018)
# 16               Manmohan Singh   (born 1932)
# 17                Narendra Modi   (born 1950)
#
#                                        Term_of_office  \
# ...

# %% [markdown]
# Q10: Write a python program to display list of 50 Most expensive cars in the world (i.e. Car name ,Description and Price) from https://www.motor1.com/
# This task will be done in following steps:
# 1. First get the webpage https://www.motor1.com/
# 2. Then You have to click on the List option from Dropdown menu on left side.
# 3. Then click on 50 most expensive cars in the world..

# %%
#first connect it to the driver
driver=webdriver.Chrome(r"D:\chromedriver_win32.zip\chromedriver.exe")

#opening motor1 page on automated chrome browser
driver.get("https://www.motor1.com/")

# %%
#open the features page
product=driver.find_element(By.XPATH,'//li[@class="grand left top mobile dropdown"]')
product.click()
time.sleep(10)

# %%
#click on 50 most expensive cars in the world 
product=driver.find_element(By.XPATH,'//a[@href="/features/308149/most-expensive-new-cars-ever/"]')
product.click()

# %%
Car_name=[]
Description=[]
Price=[]

car=driver.find_elements(By.XPATH,"//h3[@class='subheader']")#scrap car name from the given page
price=driver.find_elements(By.TAG_NAME,"strong")#scrap the respective price of the car
description=driver.find_elements(By.TAG_NAME,"p")#scrap the respective car description 
   
    
for i in car:
    Car_name.append(i.text)
    
for j in description:
    Description.append(j.text)
    
for k in price:
    Price.append(k.text)

# %%
#create the dataframe from the above data
df=pd.DataFrame({'Car_name':Car_name[:50],'Description':Description[:50],'Price':Price[:50]})
df
# Out:
#                            Car_name  \
# 0                         Drako GTE
# 1                     De Tomaso P72
# 2                 Ferrari LaFerrari
# 3                     Pagani Huayra
# 4                      McLaren Elva
# 5                       Czinger 21C
# 6                     Ferrari Monza
# 7                Gordon Murray T.33
# 8                 Koenigsegg Gemera
# 9                       Zenvo TSR-S
# 10               Hennessey Venom F5
# 11                  Bentley Bacalar
# 12    Hispano Suiza Carmen Boulogne
# 13           Bentley Mulliner Batur
# 14                     Deus Vayanne
# 15                      SSC Tuatara
# 16                      Lotus Evija
# 17              Aston Martin Vulcan
# 18                       Delage D12
# 19                McLaren Speedtail
# 20                     Rimac Nevera
# 21                    Pagani Utopia
# 22             Pininfarina Battista
# 23                Ferrari FXX K Evo
# 24               Gordon Murray T.50
# ...
